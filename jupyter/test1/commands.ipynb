# %%
import os
import pandas
os.listdir("supermarkets")
# Out:
# ['supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  'supermarkets-commas.txt']

# %%
os.listdir()
# Out:
# ['Testings.ipynb',
#  '.DS_Store',
#  'supermarkets',
#  'commands.ipynb',
#  '.ipynb_checkpoints']

# %%
df1=pandas.read_csv("supermarkets/supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets/supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import openpyxl
df3=pandas.read_excel("supermarkets/supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets/supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets/supermarkets-semi-colons.txt", separator=";")
df5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-87f1faa3368e> in <module>
# ----> 1 df5=pandas.read_csv("supermarkets/supermarkets-semi-colons.txt", separator=";")
#       2 df5
#
# TypeError: read_csv() got an unexpected keyword argument 'separator'

# %%
pandas.read_csv?
#help as seperator is sep actually

# %%
df5=pandas.read_csv("supermarkets/supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#if header not there then
#df6= pandas.read_csv("supermarkets/data.txt", header=None)
#df6
#columns
#df6.columns=["ID", "Adress", "City", "Zip", "Country", "Name","Employees"]
#own index column 
#df7=df6.set_index("ID") as the method doesnt update
#or you can df6.set_index("ID",inplace=True)
#old index column is deleted and new column is copied
# df6.set_index("ID",inplace=True, )

# %%
#look at out 24 rop row is column index leftmost row is row index
df5.set_index("ID")
#not in place
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df9=df5.set_index("ID")
#in place
#df5.set_index("ID", inplace=True)
###SETTING COLUMNS AS INDEX
#doing df5.set_index("adress", inplace=True) will delete old index
#here ID will be deleted and adress swapped
# use df5.set_index("name", inplace=True, drop=False)
#here address as index deleted but name is not swapped to index it is copied

# %%
###HOW TO SLICE AND DELETE COLUMNS ETC
df5=pandas.read_csv("supermarkets/supermarkets-semi-colons.txt", sep=";")


df6=df5.set_index("Address", drop=False)
df6
#note ID was not deleted neither was address

##BEGGINING the LABEL INDEXING how to take a piece of the table
#not in place
df10=df6.loc["3666 21st St":"1056 Sanchez St","State":"Name"]
#list(df6.loc["3666 21st St",:])

# %%
df10
# Out:
#                             State Country          Name
# Address
# 3666 21st St             CA 94114     USA       Madeira
# 735 Dolores St           CA 94119     USA   Bready Shop
# 332 Hill St      California 94114     USA   Super River
# 3995 23rd St             CA 94114     USA    Ben's Shop
# 1056 Sanchez St        California     USA       Sanchez

# %%
df5=pandas.read_csv("supermarkets/supermarkets-semi-colons.txt", sep=";")
#INDEX LOC read next in run this then do next
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.iloc[1:3,1:3]
#3 not included remember with label loc
# Out:
#           Address           City
# 1  735 Dolores St  San Francisco
# 2     332 Hill St  San Francisco

# %%
#Deleting not an inplace operation
df5.drop("City",1)
# the one means that column will be deleted
# the 0 means that row will be deleted
#not in place
# Out:
#    ID          Address             State Country          Name  Employees
# 0   1     3666 21st St          CA 94114     USA       Madeira          8
# 1   2   735 Dolores St          CA 94119     USA   Bready Shop         15
# 2   3      332 Hill St  California 94114     USA   Super River         25
# 3   4     3995 23rd St          CA 94114     USA    Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA       Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA    Richvalley         20

# %%
#add column
df5["Continent"]=df5.shape[0]*["North America"]
df5
#continent added
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
#df5.shape
#returns (rows, shape)
#df5.shape[0]
#this is the number of rows
#df5.shape[0]*["North America"]
#this gives rows times the list 

#####MODIFYING THE COLUMN
df5["Continent"]=df5["Country"]+","+"North America"
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees          Continent
# 0          8  USA,North America
# 1         15  USA,North America
# 2         25  USA,North America
# 3         10  USA,North America
# 4         12  USA,North America
# 5         20  USA,North America

# %%
### ADDING A NEW ROW
df5_t=df5.T
df5_t
#transpose
# Out:
#                            0                  1                  2  \
# ID                         1                  2                  3
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
#                            3                  4                  5
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# ...

# %%
df5_t["My_Index"]=["1","VasantKunj","Delhi","Delhi","India","Dead",3,"asia"]
df5_t
# Out:
#                            0                  1                  2  \
# ID                         1                  2                  3
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
#                            3                  4                  5    My_Index
# ID                         4                  5                  6           1
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St  VasantKunj
# City           San Francisco      San Francisco      San Francisco       Delhi
# ...

# %%
d5=df5_t.T
d5
# Out:
#          ID          Address           City             State Country  \
# 0         1     3666 21st St  San Francisco          CA 94114     USA
# 1         2   735 Dolores St  San Francisco          CA 94119     USA
# 2         3      332 Hill St  San Francisco  California 94114     USA
# 3         4     3995 23rd St  San Francisco          CA 94114     USA
# 4         5  1056 Sanchez St  San Francisco        California     USA
# 5         6  551 Alvarado St  San Francisco          CA 94114     USA
# My_Index  1       VasantKunj          Delhi             Delhi   India
#
#                   Name Employees          Continent
# 0              Madeira         8  USA,North America
# 1          Bready Shop        15  USA,North America
# 2          Super River        25  USA,North America
# 3           Ben's Shop        10  USA,North America
# 4              Sanchez        12  USA,North America
# 5           Richvalley        20  USA,North America
# ...

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
import certifi
import ssl
from geopy.geocoders import ArcGIS
ctx = ssl.create_default_context(cafile=certifi.where())
geopy.geocoders.options.default_ssl_context = ctx

# %%
nom=ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292200397371, -122.43169700840102, 0.0))

# %%
# Out:
# Help on class ArcGIS in module geopy.geocoders.arcgis:
#
# class ArcGIS(geopy.geocoders.base.Geocoder)
#  |  ArcGIS(username=None, password=None, *, referer=None, token_lifetime=60, scheme=None, timeout=DEFAULT_SENTINEL, proxies=DEFAULT_SENTINEL, user_agent=None, ssl_context=DEFAULT_SENTINEL, adapter_factory=None, auth_domain='www.arcgis.com', domain='geocode.arcgis.com')
#  |
#  |  Geocoder using the ERSI ArcGIS API.
#  |
#  |  Documentation at:
#  |      https://developers.arcgis.com/rest/geocode/api-reference/overview-world-geocoding-service.htm
#  |
#  |  Method resolution order:
#  |      ArcGIS
#  |      geopy.geocoders.base.Geocoder
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, username=None, password=None, *, referer=None, token_lifetime=60, scheme=None, timeout=DEFAULT_SENTINEL, proxies=DEFAULT_SENTINEL, user_agent=None, ssl_context=DEFAULT_SENTINEL, adapter_factory=None, auth_domain='www.arcgis.com', domain='geocode.arcgis.com')
# ...
